# %%
import numpy as np
# Plotting
import matplotlib.pyplot as plt
# colors is useful for mapping colors to numbers
from matplotlib import colors

from sklearn.neighbors import RadiusNeighborsClassifier as kNN

# %%
from sklearn.datasets import make_blobs

dataset1 = 5000
dataset2 = 100

X, y = make_blobs(n_samples=[dataset1,dataset2], centers=[(1,1),(3,3)], n_features=2,
                  random_state=0)

# using color maps
cmap = colors.ListedColormap(['blue','coral'])

ax=plt.axes()
ax.scatter(X[:,0],X[:,1],color=cmap(y))
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
# Out:
# Text(0, 0.5, '$x_2$')

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# create X (features) and y (response)
X = iris.data[:,[0,1]]
y = iris.target

# %%
def plot_classifier_boundary(model, X, y, h=.05):
    # this function can be used with any sklearn classifier
    # ready for two classes but can be easily extended
    cmap_light = colors.ListedColormap(['lightsteelblue', 'peachpuff','lightgreen'])
    x_min, x_max = X[:, 0].min()-.2, X[:, 0].max()+.2
    y_min, y_max = X[:, 1].min()-.2, X[:, 1].max()+.2
    # generate a grid with step h
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    # the method ravel flattens xx and yy
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=cmap_light)
    plt.xlim((x_min,x_max))
    plt.ylim((y_min,y_max))

cmap = colors.ListedColormap(['blue','orange','green'])

# %%
model=kNN(n_neighbors=20).fit(X,y)
plot_classifier_boundary(model,X,y)

plt.scatter(X[:,0],X[:,1],color=cmap(y))
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
# Out:
# c:\Users\toni\miniconda3\envs\machinelearning\lib\site-packages\sklearn\neighbors\_classification.py:462: FutureWarning: Passing additional keyword parameters has no effect and is deprecated in 1.0. An error will be raised from 1.2 and beyond. The ignored keyword parameter(s) are: dict_keys(['n_neighbors']).
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\toni\Documents\Privat\Bildung\Studium\Master\LMU Informatik\Auslanssemester\Vorlesungen\Machine Learning\Assigment\ML_Assignment\datasets.ipynb Cell 5' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/toni/Documents/Privat/Bildung/Studium/Master/LMU%20Informatik/Auslanssemester/Vorlesungen/Machine%20Learning/Assigment/ML_Assignment/datasets.ipynb#ch0000003?line=0'>1</a> model=kNN(n_neighbors=20).fit(X,y)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/toni/Documents/Privat/Bildung/Studium/Master/LMU%20Informatik/Auslanssemester/Vorlesungen/Machine%20Learning/Assigment/ML_Assignment/datasets.ipynb#ch0000003?line=1'>2</a> plot_classifier_boundary(model,X,y)
#       <a href='vscode-notebook-cell:/c%3A/Users/toni/Documents/Privat/Bildung/Studium/Master/LMU%20Informatik/Auslanssemester/Vorlesungen/Machine%20Learning/Assigment/ML_Assignment/datasets.ipynb#ch0000003?line=3'>4</a> plt.scatter(X[:,0],X[:,1],color=cmap(y))
#       <a href='vscode-notebook-cell:/c%3A/Users/toni/Documents/Privat/Bildung/Studium/Master/LMU%20Informatik/Auslanssemester/Vorlesungen/Machine%20Learning/Assigment/ML_Assignment/datasets.ipynb#ch0000003?line=4'>5</a> plt.xlabel('$x_1$')
#
# c:\Users\toni\Documents\Privat\Bildung\Studium\Master\LMU Informatik\Auslanssemester\Vorlesungen\Machine Learning\Assigment\ML_Assignment\datasets.ipynb Cell 4' in plot_classifier_boundary(model, X, y, h)
#       <a href='vscode-notebook-cell:/c%3A/Users/toni/Documents/Privat/Bildung/Studium/Master/LMU%20Informatik/Auslanssemester/Vorlesungen/Machine%20Learning/Assigment/ML_Assignment/datasets.ipynb#ch0000002?line=7'>8</a> xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
#       <a href='vscode-notebook-cell:/c%3A/Users/toni/Documents/Privat/Bildung/Studium/Master/LMU%20Informatik/Auslanssemester/Vorlesungen/Machine%20Learning/Assigment/ML_Assignment/datasets.ipynb#ch0000002?line=8'>9</a>                      np.arange(y_min, y_max, h))
#      <a href='vscode-notebook-cell:/c%3A/Users/toni/Documents/Privat/Bildung/Studium/Master/LMU%20Informatik/Auslanssemester/Vorlesungen/Machine%20Learning/Assigment/ML_Assignment/datasets.ipynb#ch0000002?line=9'>10</a> # the method ravel flattens xx and yy
# ---> <a href='vscode-notebook-cell:/c%3A/Users/toni/Documents/Privat/Bildung/Studium/Master/LMU%20Informatik/Auslanssemester/Vorlesungen/Machine%20Learning/Assigment/ML_Assignment/datasets.ipynb#ch0000002?line=10'>11</a> Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
#      <a href='vscode-notebook-cell:/c%3A/Users/toni/Documents/Privat/Bildung/Studium/Master/LMU%20Informatik/Auslanssemester/Vorlesungen/Machine%20Learning/Assigment/ML_Assignment/datasets.ipynb#ch0000002?line=11'>12</a> Z = Z.reshape(xx.shape)
#      <a href='vscode-notebook-cell:/c%3A/Users/toni/Documents/Privat/Bildung/Studium/Master/LMU%20Informatik/Auslanssemester/Vorlesungen/Machine%20Learning/Assigment/ML_Assignment/datasets.ipynb#ch0000002?line=12'>13</a> plt.contourf(xx, yy, Z, cmap=cmap_light)
#
# File c:\Users\toni\miniconda3\envs\machinelearning\lib\site-packages\sklearn\neighbors\_classification.py:569, in RadiusNeighborsClassifier.predict(self, X)
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=553'>554</a> def predict(self, X):
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=554'>555</a>     """Predict the class labels for the provided data.
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=555'>556</a>
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=556'>557</a>     Parameters
#    (...)
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=565'>566</a>         Class labels for each data sample.
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=566'>567</a>     """
# --> <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=568'>569</a>     probs = self.predict_proba(X)
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=569'>570</a>     classes_ = self.classes_
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=571'>572</a>     if not self.outputs_2d_:
#
# File c:\Users\toni\miniconda3\envs\machinelearning\lib\site-packages\sklearn\neighbors\_classification.py:628, in RadiusNeighborsClassifier.predict_proba(self, X)
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=624'>625</a>     classes_ = [self.classes_]
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=626'>627</a> if self.outlier_label_ is None and outliers.size > 0:
# --> <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=627'>628</a>     raise ValueError(
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=628'>629</a>         "No neighbors found for test samples %r, "
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=629'>630</a>         "you can try using larger radius, "
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=630'>631</a>         "giving a label for outliers, "
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=631'>632</a>         "or considering removing them from your dataset." % outliers
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=632'>633</a>     )
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=634'>635</a> weights = _get_weights(neigh_dist, self.weights)
#     <a href='file:///c%3A/Users/toni/miniconda3/envs/machinelearning/lib/site-packages/sklearn/neighbors/_classification.py?line=635'>636</a> if weights is not None:
#
# ValueError: No neighbors found for test samples array([4320, 4321, 4372, 4373, 4400, 4401, 4402, 4403, 4452, 4453, 4454,
#        4455, 4480, 4481, 4482, 4483, 4484, 4532, 4533, 4534, 4535, 4536,
#        4537, 4538, 4539, 4540], dtype=int64), you can try using larger radius, giving a label for outliers, or considering removing them from your dataset.

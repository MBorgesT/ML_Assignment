# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from matplotlib import pyplot as plt
from sklearn.model_selection import GridSearchCV
from utils import plot_2d, plot_classifier_boundary, test_model, test_model_with_standard_scaler
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # SVM radial basis vs SVM polynomial

# %% [markdown]
# ## POLY performing better

# %% [markdown]
# Same as with linear kernel it is hard to outperform RBF with polynomial kernel. I used the sama dataset again, but this time with only 2 features.

# %%
def G_SVC_poly(): # generating data for a better poly kernel performance

 
    X, y = datasets.make_blobs(
        n_samples=[100, 5000], 
        centers=[(3,5),(6,5)],             
        n_features=2, 
        cluster_std=[0.5, 1],
        random_state=42, 
        shuffle=False)


    return X, y

# %%
X_poly, y_poly = G_SVC_poly()
plot_2d(X_poly, y_poly)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_poly,
                                                    y_poly,
                                                    test_size=.33,
                                                    random_state=42)

# %%
# parameter tuning for rbf kernel

param_grid_rbf = {'C': [0.001,0.01,0.1,1,5,10,15,20,30,40,50,60,70,80,90,100],
                  'kernel': ['rbf'],
                  'gamma': [0.0001, 0.001, 0.01, 0.1, 1]}

grid_rbf = GridSearchCV(SVC(), param_grid_rbf)
grid_rbf.fit(X_train, y_train);

# %%
model_rbf = SVC(kernel='rbf',
                C=grid_rbf.best_params_['C'],
                gamma=grid_rbf.best_params_['gamma'],
                random_state=42)

# %%
# parameter tuning for poly kernel

param_grid_poly = {'C': [0.001,0.01,0.1,1,5,10,15,20,30, 40, 50],
                   'kernel': ['poly'],
                   'gamma': [0.0001, 0.001, 0.01, 0.1, 1],
                   'degree': [1, 2, 3]}


grid_poly = GridSearchCV(SVC(), param_grid_poly)
grid_poly.fit(X_train, y_train);

# %%
model_poly = SVC(kernel='poly',
                 degree=grid_poly.best_params_['degree'],
                 C=grid_poly.best_params_['C'],
                 gamma=grid_poly.best_params_['gamma'],
                 random_state=42)

# %%
test_model(model_poly, X_poly, y_poly, n_tests=100)
# Out:
# AUC score: 0.919

# %%
test_model(model_rbf, X_poly, y_poly, n_tests=100);
# Out:
# AUC score: 0.895

# %% [markdown]
# The tests was done 100 times again, because of the small difference between models performances. It tends to give better results with polynomial kernel, but not by much.

# %% [markdown]
# ## RBF performing better

# %% [markdown]
# This task was again pretty easy. The power of RBF kernel lets the user create quite fancy datasets, which the SVC with RBF kernel classifies with very high accuracy. This time it is a situasion with many "blobs" with 2 features.

# %%
def G_SVC_rbf(): # generating data for a better rbf kernel performance

    X, y = datasets.make_blobs(
        n_samples=1500,
        n_features=2,
        centers=220,
        cluster_std=.16,
        random_state=42
    )
    y = y % 2 
   
    return X, y

# %%
X_rbf, y_rbf = G_SVC_rbf()

# %%
plot_2d(X_rbf, y_rbf)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_rbf,
                                                    y_rbf,
                                                    test_size=.33,
                                                    random_state=42)

# %%
# parameter tuning for rbf kernel

param_grid_rbf = {'C': [0.001,0.01,0.1,1,5,10,15,20,30,40,50,60,70,80,90,100],
                  'kernel': ['rbf'],
                  'gamma': [0.0001, 0.001, 0.01, 0.1, 1]}

grid_rbf = GridSearchCV(SVC(), param_grid_rbf)
grid_rbf.fit(X_train, y_train);

# %%
model_rbf = SVC(kernel='rbf',
                random_state=42,
                C=grid_rbf.best_params_['C'],
                gamma=grid_rbf.best_params_['gamma'])

# %%
# parameter tuning for poly kernel

param_grid_poly = {'C': [0.001,0.01,0.1,1,5,10,15,20,30, 40, 50],
                   'kernel': ['poly'],
                   'gamma': [0.0001, 0.001, 0.01, 0.1, 1],
                   'degree': [2]}

grid_poly = GridSearchCV(SVC(), param_grid_poly)
grid_poly.fit(X_train, y_train);

# %%
model_poly = SVC(kernel='poly',
                 degree=grid_poly.best_params_['degree'],
                 C=grid_poly.best_params_['C'],
                 gamma=grid_poly.best_params_['gamma'],
                 random_state=42)

# %%
test_model(model_poly, X_rbf, y_rbf)
# Out:
# AUC score: 0.533

# %%
test_model(model_rbf, X_rbf, y_rbf);
# Out:
# AUC score: 0.919

# %% [markdown]
# RBF expressiveness lets the model classify data with high accuracy, whereas polynomial kernel only gets a little above half of the data right, which is a really bad score. Data seems to be too complicated for the polynomial kernel, although it is important to state that the degree of the polynomial was restricted because of the limited computational power of my computer. There's a possibility that higher degrees of the kernel would work better, but it could not be examined.
